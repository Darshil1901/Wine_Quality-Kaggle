# %% [markdown]
# **Step 1: Import Libraries**

# %%
import numpy as ny
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')

# %% [markdown]
# **Step 2: Load the Data**

# %%
df = pd.read_csv(r'E:\\ftn\\data set\\p Data set\\DONE\\wine.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# **Step 3: Explore the Data**

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# **Step 4: Data Cleaning**

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.columns.tolist()
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
df.nunique()
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %% [markdown]
# **Step 5: Data Exploration**

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# **Step 6: Analysis and Visualization**

# %%
qc = df['quality'].value_counts()
plt.figure(figsize = (12,6))
plt.bar(qc.index, qc, color = "pink")
plt.title("Count Plot of quality")
plt.xlabel("Quality")
plt.ylabel("Count")
plt.grid(axis = "y")
plt.show()

# %%
#seaborn #when u have to visualize the category values then we will use the swarmplot 
plt.figure(figsize = (12,6))
sns.swarmplot(x = "quality", y = "alcohol", data = df, palette = "viridis")
plt.title("Count Plot of quality")
plt.xlabel("Quality")
plt.ylabel("Alcohol")
plt.grid(axis = "y")
plt.show()

# %% [markdown]
# This plot depicts thats the higher point density in specific regions shows the concentration indicating where the majority of the data points cluster. The points isolated and are far away from the clusters shows the outliers

# %%
#seaborn #when u have to visualize the distrubution (multiple groups) numerical values then we will use the violinplot
df['quality'] = df['quality'].astype(str)
plt.figure(figsize = (12,6))
sns.violinplot(x = "quality", y = "alcohol", data = df, palette = {"3":"lightcoral", "4":"lightblue", "5":"lightgreen", "6":"gold", "7":"lightskyblue", "8":"lightpink"}, alpha = 0.9)
plt.title("Violin Plot for Quality and Alcohol")
plt.xlabel("Quality")
plt.ylabel("Alcohol")
plt.grid(axis = "y")
plt.show()

# %%
#boxplot to summarize the visualization
plt.figure(figsize = (10,6))
sns.boxplot(x = "quality", y = "alcohol", data = df, palette = {"3":"lightcoral", "4":"lightblue", "5":"lightgreen", "6":"gold", "7":"lightskyblue", "8":"lightpink"})
plt.title("BoxPlot for Quality and Alcohol")
plt.xlabel("Quality")
plt.ylabel("Alcohol")
plt.grid(axis = "y")
plt.show()

# %%
#relationshp between patterns and corelations we will use heat map
plt.figure(figsize = (15,10))
sns.heatmap(df.corr(), annot = True, fmt = '.2f', cmap = "Pastel1", linewidths = 2)
plt.title("Correlation HeatMap")
plt.show()

# %%
#MINE
plt.figure(figsize = (12,6))
sns.swarmplot(x = "quality", y = "pH", data = df, palette = "viridis")
plt.title("pH plot for Quality")
plt.xlabel("Quality")
plt.ylabel("PH")
plt.grid(axis = "y")
plt.show()

# %%
#MINE
plt.figure(figsize = (12,6))
sns.boxplot(x = "quality", y = "residual sugar", data = df, palette = "viridis")
plt.title("Residual Sugar plot for Quality")
plt.xlabel("Quality")
plt.ylabel("Residual Sugar")
plt.grid(axis = "y")
plt.show()

# %%
#MINE
plt.figure(figsize = (12,6))
sns.violinplot(x = "quality", y = "free sulfur dioxide", data = df, palette = "viridis")
plt.title("Free Sulfur Dioxide plot for Quality")
plt.xlabel("Quality")
plt.ylabel("Free Sulfur Dioxide")
plt.grid(axis = "y")
plt.show()

# %%
#MINE
plt.figure(figsize = (12,6))
sns.swarmplot(x = "quality", y = "fixed acidity", data = df, palette = "Pastel2")
plt.title("Fixed Acididty plot for Quality")
plt.xlabel("Quality")
plt.ylabel("Fixed Acidity")
plt.grid(axis = "y")
plt.show()

# %%
#MINE
plt.figure(figsize = (12,6))
sns.violinplot(x = "quality", y = "density", data = df, palette = "Pastel1", alpha = 0.5)
plt.title("Density plot for Quality")
plt.xlabel("Quality")
plt.ylabel("Density")
plt.grid(axis = "y")
plt.show()

# %%
#Univariate Analysis_1
sns.set(style="darkgrid")
plt.figure(figsize=(12, 6))
plt.title('Univariate Analysis of volatile acidity', fontsize=20)
sns.histplot(data = df, x = 'volatile acidity', bins=30, kde=True, color='red')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
#Univariate Analysis_2
sns.set(style="darkgrid")
plt.figure(figsize=(12, 6))
plt.title('Univariate Analysis of chlorides ', fontsize=20)
sns.histplot(data = df, x = 'chlorides', bins=30, kde=True, color='green')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
#Univariate Analysis_3
sns.set(style="darkgrid")
plt.figure(figsize=(12, 6))
plt.title('Univariate Analysis of fixed acidity ', fontsize=20)
sns.histplot(data = df, x = 'fixed acidity', bins=30, kde=True, color='yellow')
plt.tight_layout(rect=[0.95, 0.03, 1, 1])
plt.show()

# %%
# Bivariate Analysis_1
plt.figure(figsize=(12, 6))
plt.title('Fixed Acidity vs Quality', fontsize=16)
sns.scatterplot(data = df, x="quality", y="fixed acidity", color='teal')
plt.ylabel('fixed acidity')
plt.xlabel('Quality')
plt.tight_layout()
plt.show()

# %%
# Bivariate Analysis_2
plt.figure(figsize=(12, 6))
plt.title('volatile acidity vs Quality', fontsize=16)
sns.scatterplot(data = df, x="quality", y="volatile acidity", color='teal')
plt.ylabel('volatile acidity')
plt.xlabel('Quality')
plt.tight_layout()
plt.show()
